# %% [markdown]
# ### 장지의 플레이리스트 확인

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
# pip install oauth2client

# %%
api_key = '-'
youtube_api_service_name = 'youtube'
youtube_api_version = 'v3'

youtube = build(youtube_api_service_name, youtube_api_version, developerKey = api_key)

# %%
search_response = youtube.search().list(q = '장지',
                                       order = 'relevance',
                                       part = 'snippet',
                                       maxResults = 50).execute()

# %%
channel_id = search_response['items'][0]['snippet']['channelId']

# %%
playlists = youtube.playlists().list(channelId = channel_id,
                                    part = 'snippet',
                                    maxResults = 50).execute()

# %%
ids = []
titles = []
for i in playlists['items']:
    ids.append(i['id'])
    titles.append(i['snippet']['title'])
    
df = pd.DataFrame([ids, titles])

# %%
df = df.T

# %%
df.columns = ['PlayLists', 'Titles']

# %%
df
# Out:
#                              PlayLists                  Titles
# 0   PLixgYKkP_Mjjdr5b2uUfXe2TSaDh0w00r                      경매
# 1   PLixgYKkP_Mjim7ZeKNH9tYir9WhOX2sQ-                   부자의 삶
# 2   PLixgYKkP_MjjoIm2Xxwiy765bj9E-5hKZ           장지x백설희 부부 컨텐츠
# 3   PLixgYKkP_Mjj9MlR3iVxSqUh4c0bJYBr7           ▶핵심 컨텐츠 공략 영상
# 4   PLixgYKkP_Mjg-cS0SFJCVaZqEsNcj7HNX              【장지의 던파교실】
# 5   PLixgYKkP_MjgcCam2LcbGk3d0YdIU9eYA          ★던파 스토리 한눈에 보기
# 6   PLixgYKkP_Mjgv4Ua6QFRnem7rMD8GnmHd              【장지의 골목던파】
# 7   PLixgYKkP_Mjjn9OhdnU8SrxcBdlfCfRBe      ▶리얼 무자본 캐릭터 육성 컨텐츠
# 8   PLixgYKkP_MjgOfPKkIT9KZHTBIp3xelel  ▶던파 랭커 초대석 【템귀/고수/네임드】
# 9   PLixgYKkP_Mjhpp1SK8otYJo3bbF2UNUzu      ▶캐릭터 강의 【스킬트리, 꿀팁】
# 10  PLixgYKkP_Mjit9MSfaToBzlOcIbkb-Y19                ▶스펙업 가이드
# 11  PLixgYKkP_MjjGG7dseEIQ8sCIYTuzqXm7            【캐릭터 추천 가이드】
# 12  PLixgYKkP_MjgXHc6_iswhc1u40mXu5r1F     【던파 페스티벌】 FULL ver.
# 13  PLixgYKkP_Mjg_h4f_2sMFxK9L21eWb6Kc            【던파 M / 모바일】
# 14  PLixgYKkP_Mji5C-bWAUkm4edHsiCXVwzo               【뒤풀이 게임들】
# 15  PLixgYKkP_Mji911WQD8z51hqMnhkLx03A         【스킬커마】 탈리스만 & 룬
# 16  PLixgYKkP_MjgPTvJEb7ZI15QLOILiSw2Q            ▶꼭 봐야될 추천 영상
# 17  PLixgYKkP_MjgBQ6ZX4PYnke3Q3-R2LkU8              던파의 연간 핫이슈
# 18  PLixgYKkP_MjgMnV278LzMzxSj_nGnHxv7             생방 하이라이트ㅋㅋㅋ
# 19  PLixgYKkP_MjgVvGSAO1b_yJuUit6QnMHS        DPL 【던파 프리미어 리그】
# 20  PLixgYKkP_MjhbBnCndnAlUE3UmjQ5lb1R             ▶요약정리/분석/설명
# 21  PLixgYKkP_MjgWh8kxiITX5Ef_--EsVDwo                  추천 가이드
# 22  PLixgYKkP_MjjJ2lr3uoQWSRqOZmKX1iEg                      버그
# 23  PLixgYKkP_MjjdCfjFJHgVWK3YDnsUVIYN          ★득템/지옥파티 하이라이트
# 24  PLixgYKkP_MjhFE4jTkuop_3fiky-okjNt          【클리어영상】 퍼스트 서버
# 25  PLixgYKkP_MjgH6CF8njElM1CI2cQD9EOy            【클리어영상】 특수던전
# 26  PLixgYKkP_MjitAXtSfUGBCl430XYQZDs9         【그때 그시절】 안톤 레이드
# 27  PLixgYKkP_MjgaFaMO3CRkx-Qg8x3OSthQ                  1인 플레이
# 28  PLixgYKkP_Mji591DNASEkIZZGHu8-BD4x                  던파 실험실
# 29  PLixgYKkP_Mjgp7tCl7pKjPzMmBqRE0czZ            【꿀팁/스킬트리/설명】
# 30  PLixgYKkP_MjgCa289bOK3x9usXT-C_JM_                   콤보 영상
# 31  PLixgYKkP_Mji6axZC4O4UIimtJenP-_zq            【리뷰】 해외 던파소식
# 32  PLixgYKkP_MjhMy5ye3_0NVkzjHrUInep1               【리뷰】 그 외에
# 33  PLixgYKkP_Mjg4vokOwY7s92EtrG0MKoXw             【리뷰】 개발자 노트
# 34  PLixgYKkP_MjhkWj97m-JBY584djSx7fn2            【리뷰】 이벤트&패키지
# 35  PLixgYKkP_Mjgk-v8Ijsdf9fDSEbockJOr         【리뷰】 업데이트&공지&점검
# 36  PLixgYKkP_Mjg4UWhVU7izJrKFjcuYiIxh              【리뷰】 퍼스트서버
# 37  PLixgYKkP_MjgFoHovfTr299qeStwIrQpm                 봉자/랜덤상자
# 38  PLixgYKkP_Mjhx18tTfpA1drFdhGHE5age                 ▶던파 스토리
# 39  PLixgYKkP_Mjgkb4qOssTWoezM0xKyQnna                     밸런스
# 40  PLixgYKkP_Mjg8hJMGv9gIbaJ8r3tyCF0W                    썰 풀기
# 41  PLixgYKkP_MjiRN5q56LZaSlJkDbKZECQ0          【강화/증폭/개조/딜체크】
# 42  PLixgYKkP_MjgukyZsF2mCD5EHmBowgIeg                  방송 컨텐츠

# %%
# pip install resource

# %% [markdown]
# ### 특정 플레이리스트의 영상목록 가져오기

# %% [markdown]
# # 던파 M
# - '【던파 M / 모바일】' 목록의 영상들 불러오기.

# %%
# '【던파 M / 모바일】'의 영상들

update_videos = df['PlayLists'][13]

playlist_videos = youtube.playlistItems().list(playlistId = update_videos,
                                              part = 'snippet',
                                              maxResults = 50) # 50개 동영상 뽑아보기
playlistitems_list_response = playlist_videos.execute()

video_names = []
video_ids = []
date = []

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])

video_df = pd.DataFrame([date, video_names, video_ids]).T
video_df.columns = ['Date', 'Title', 'IDS']

# %%
video_df
# Out:
#                     Date                                              Title  \
# 0   2022-04-29T10:53:36Z                                  던파 모바일 '신규 스킬' 유출
# 1   2022-04-28T08:20:21Z                         지금 당장 꿀 빠세요!!! 제발 (던파 모바일)
# 2   2022-04-28T07:43:06Z           항마력 1.5로 '로터스 레이드 3페이즈' 클리어 성공! (던파 모바일)
# 3   2022-04-28T05:24:22Z  신규 직업 + 패키지, 공짜 강화 이벤트, 로터스 레이드 추가! 자세하게 설명 해드...
# 4   2022-04-28T05:18:11Z                           +15강 오너 인사 드립니다 (던파 모바일)
# 5   2022-04-26T22:55:39Z                      그때 그시절, '꿈'을 이뤄보겠습니다 (던파 모바일)
# 6   2022-04-24T13:31:40Z                       '소울브링어' 진짜 심각합니다... (던파 모바일)
# 7   2022-04-18T10:20:32Z                    【던파 모바일】 '지옥파티 초대장' 공짜로 얻는 법 꿀팁
# 8   2022-04-14T07:19:15Z        【던파 모바일】 로터스 레이드, 신규 직업 확정! 신규 쌉사기 에픽 옵션 공개
# 9   2022-04-07T00:24:59Z       【던파 모바일】 ㅈ간지 무기 '월광' 떴다!! 에픽 쏟아지는 지옥파티 하이라이트
# 10  2022-04-06T03:25:29Z                         【던파 모바일】 신규 콘텐츠, 패키지 대거 유출
# 11  2022-04-03T03:38:19Z    드디어... 게임이 도박장을 이겼습니다...! (던파 모바일 인기, 매출 1위 달성)
# 12  2022-03-30T03:34:53Z       【던파 모바일】 '1차 각성' 하는 법 + 스킬 포인트, TP 얻는 꿀팁 총정리
# 13  2022-03-29T01:54:28Z                      【던파 모바일】 레어 아바타, 얼마나 질러야 나올까?
# 14  2022-03-29T01:28:47Z                            【던파 모바일】 뽑기 뽕맛 미쳤습니다...
# 15  2022-03-28T03:16:56Z                 【던파 모바일】 찍먹 하려다가 결투장 '낭인' 찍었습니다...
# 16  2022-03-26T04:52:09Z               【던파 모바일】 깜짝 공개된 '신규 직업' 모든 스킬, 정보 리뷰
# 17  2022-03-24T05:58:10Z                【던파 모바일】 가성비 & 효율 좋은 패키지, 과금 요소 총정리
# 18  2022-03-24T04:50:57Z  '던파 모바일' 시작하는 초보 유저를 위한 가이드 (앱플레이어, 사전 예약 보상, ...
# 19  2022-03-23T05:05:18Z  【던파 모바일】 서버, 캐릭터 추천 가이드 (무자본, 노가다, 파티, 귀족, 과금,...
# 20  2022-02-07T09:57:50Z               '던파 모바일' 출시 일정 공개! + 신규 캐릭터 추가 (던파M)
# 21  2021-12-21T07:47:15Z     그 시절, 추억의 던파가 돌아왔다! '던파 모바일' 실제 플레이 (DNFM CBT)
# 22  2021-11-05T19:33:23Z     던파M 출시 확정! 공개된 정보 총정리 (캐릭터, 컨텐츠, 스펙업 요소, 과금 등)
# 23  2019-12-05T22:20:27Z                            【던파M】 로터스 레이드 실제 플레이 영상
# 24  2020-06-04T16:07:25Z                    【던파】 던파M 신규 전직 등장! 실제 플레이 영상 리뷰
# 25  2019-12-30T09:59:36Z                               【던파M】 시로코 레이드 미리보기?!
# 26  2019-12-05T22:24:10Z                    (던파) 윤명진 디렉터가 쏘아올린 작은 공. 그것은...
# 27  2019-12-05T22:23:22Z                【던파】 로터스 레이드 확정! 그런데 M...? 팩트 체크 ㄱㄱ
# 28  2019-12-05T22:21:57Z                           【던파】 속보! 로터스 레이드 영상 유출!!
# 29  2019-12-05T22:21:22Z               【던파M】 신규 던전+캐릭터 도트 유출!! 이걸 준비하고 있었네?
# 30  2019-12-05T22:20:51Z               (던파) 띵진이가 빤스런한 던파M 영상 유출?! 같이 봐봅시다ㄱㄱ
# 31  2019-12-05T22:16:37Z               【던파M】 미공개 영상 최초공개! 직업, 스토리, 인게임 미리보기
#
#             IDS
# 0   uz2bQwkj7P8
# 1   dLTenI_bupA
# 2   jPO7ak6bTGI
# 3   _PmNr8kjK3E
# 4   9AnjIAgb2vM
# 5   GdYNCkH6QN0
# 6   Dv9h1bI1yP0
# 7   daBAovdGpyk
# 8   QnpdOGtb3G0
# 9   065m6cT8idE
# 10  1e6a4kAsd0w
# 11  17k_6yGXPk8
# 12  U1uD41libVA
# 13  b8F21FZq_U0
# 14  cd1yh91PjIk
# 15  G6m--yzZR9E
# 16  Y5Lj9boMgNg
# 17  ToSeBXZOYFU
# 18  c4Wfmkct2ZA
# 19  wbndV511hg4
# 20  U8htAWBt6_Q
# 21  -CLNemKAXnk
# 22  mgwROqblYnE
# 23  RIuu6QLMzo0
# 24  Vrssz1_VAfY
# 25  mUghLqiqGAI
# 26  jDDu5XiVPd4
# 27  IDtCAEteLLA
# 28  qntgZgcrz-Q
# 29  qntUkJxSZz8
# 30  I6aj4m1Z3zE
# 31  FI5PaSXoGWY

# %% [markdown]
# #### 조회수, 좋아요, 영상길이, 제목 수집

# %%
# 해당 각 영상들의 정보 수집

import re

ids = []
dates = []
category_id = []
views = []
likes = []
dislikes = []
comments = []
title = []
mins = [] # 분
secs = [] # 초

for i in range(len(video_df)):
    request = youtube.videos().list(part = 'snippet, contentDetails, statistics',
                                   id = video_df['IDS'][i])
    response = request.execute()
    
    if response['items'] == []:
        ids.append('-')
        dates.append('-')
        category_id.append('-')
        views.append('-')
        likes.append('-')
        dislikes.append('-')
        comments.append('-')
        mins.append('-')
        secs.append('-')
    else:
        title.append(response['items'][0]['snippet']['title'])
        ids.append(video_df['IDS'][i])
        dates.append(response['items'][0]['snippet']['publishedAt'].split('T')[0])
        category_id.append(response['items'][0]['snippet']['categoryId'])
        views.append(response['items'][0]['statistics']['viewCount'])
        likes.append(response['items'][0]['statistics']['likeCount'])
        comments.append(response['items'][0]['statistics']['commentCount'])
        
update_videos_df = pd.DataFrame([title, ids, dates, category_id, views, likes, comments]).T
update_videos_df.columns = ['title', 'video_id', 'date', 'category_id', 'views', 'likes', 'comments']

# %%
update_videos_df
# Out:
#                                                 title     video_id  \
# 0                                   던파 모바일 '신규 스킬' 유출  uz2bQwkj7P8
# 1                          지금 당장 꿀 빠세요!!! 제발 (던파 모바일)  dLTenI_bupA
# 2            항마력 1.5로 '로터스 레이드 3페이즈' 클리어 성공! (던파 모바일)  jPO7ak6bTGI
# 3   신규 직업 + 패키지, 공짜 강화 이벤트, 로터스 레이드 추가! 자세하게 설명 해드...  _PmNr8kjK3E
# 4                            +15강 오너 인사 드립니다 (던파 모바일)  9AnjIAgb2vM
# 5                       그때 그시절, '꿈'을 이뤄보겠습니다 (던파 모바일)  GdYNCkH6QN0
# 6                        '소울브링어' 진짜 심각합니다... (던파 모바일)  Dv9h1bI1yP0
# 7                     【던파 모바일】 '지옥파티 초대장' 공짜로 얻는 법 꿀팁  daBAovdGpyk
# 8         【던파 모바일】 로터스 레이드, 신규 직업 확정! 신규 쌉사기 에픽 옵션 공개  QnpdOGtb3G0
# 9        【던파 모바일】 ㅈ간지 무기 '월광' 떴다!! 에픽 쏟아지는 지옥파티 하이라이트  065m6cT8idE
# 10                         【던파 모바일】 신규 콘텐츠, 패키지 대거 유출  1e6a4kAsd0w
# 11    드디어... 게임이 도박장을 이겼습니다...! (던파 모바일 인기, 매출 1위 달성)  17k_6yGXPk8
# 12       【던파 모바일】 '1차 각성' 하는 법 + 스킬 포인트, TP 얻는 꿀팁 총정리  U1uD41libVA
# 13                      【던파 모바일】 레어 아바타, 얼마나 질러야 나올까?  b8F21FZq_U0
# 14                            【던파 모바일】 뽑기 뽕맛 미쳤습니다...  cd1yh91PjIk
# 15                 【던파 모바일】 찍먹 하려다가 결투장 '낭인' 찍었습니다...  G6m--yzZR9E
# 16               【던파 모바일】 깜짝 공개된 '신규 직업' 모든 스킬, 정보 리뷰  Y5Lj9boMgNg
# 17                【던파 모바일】 가성비 & 효율 좋은 패키지, 과금 요소 총정리  ToSeBXZOYFU
# 18  '던파 모바일' 시작하는 초보 유저를 위한 가이드 (앱플레이어, 사전 예약 보상, ...  c4Wfmkct2ZA
# 19  【던파 모바일】 서버, 캐릭터 추천 가이드 (무자본, 노가다, 파티, 귀족, 과금,...  wbndV511hg4
# 20               '던파 모바일' 출시 일정 공개! + 신규 캐릭터 추가 (던파M)  U8htAWBt6_Q
# 21     그 시절, 추억의 던파가 돌아왔다! '던파 모바일' 실제 플레이 (DNFM CBT)  -CLNemKAXnk
# 22     던파M 출시 확정! 공개된 정보 총정리 (캐릭터, 컨텐츠, 스펙업 요소, 과금 등)  mgwROqblYnE
# 23                            【던파M】 로터스 레이드 실제 플레이 영상  RIuu6QLMzo0
# 24                    【던파】 던파M 신규 전직 등장! 실제 플레이 영상 리뷰  Vrssz1_VAfY
# 25                               【던파M】 시로코 레이드 미리보기?!  mUghLqiqGAI
# 26                    (던파) 윤명진 디렉터가 쏘아올린 작은 공. 그것은...  jDDu5XiVPd4
# 27                【던파】 로터스 레이드 확정! 그런데 M...? 팩트 체크 ㄱㄱ  IDtCAEteLLA
# 28                           【던파】 속보! 로터스 레이드 영상 유출!!  qntgZgcrz-Q
# 29               【던파M】 신규 던전+캐릭터 도트 유출!! 이걸 준비하고 있었네?  qntUkJxSZz8
# 30               (던파) 띵진이가 빤스런한 던파M 영상 유출?! 같이 봐봅시다ㄱㄱ  I6aj4m1Z3zE
# 31               【던파M】 미공개 영상 최초공개! 직업, 스토리, 인게임 미리보기  FI5PaSXoGWY
#
#           date category_id  views likes comments
# 0   2022-04-29          20  13869    55       27
# 1   2022-04-28          20   5860    26       12
# 2   2022-04-28          20  24573    98       25
# 3   2022-04-28          20   3944    17        9
# 4   2022-04-28          20   6060    25        9
# 5   2022-04-27          20  24658   117       26
# 6   2022-04-24          20  41651   164      214
# 7   2022-04-18          20   4177    16       11
# 8   2022-04-14          20  18289    50       24
# 9   2022-04-07          20  28326    80       44
# 10  2022-04-06          20  33130   137       53
# 11  2022-04-03          20  10594   126       68
# 12  2022-03-30          20  53856   174       30
# 13  2022-03-29          20  47927   124      136
# 14  2022-03-29          20  24275    95       37
# 15  2022-03-28          20   9963    50       17
# 16  2022-03-26          20  81141   278       92
# 17  2022-03-24          20  90737   341       88
# 18  2022-03-24          20  20563   129       27
# 19  2022-03-23          20  80060   274       77
# 20  2022-02-07          20  46368   192       73
# 21  2021-12-21          20  25205   135       40
# 22  2021-11-06          20  34266   122      175
# 23  2019-11-16          20  33480    88       47
# 24  2020-06-04          20  39784   109       47
# 25  2020-01-02          20  26024    87       25
# 26  2018-12-30          20  14722    54       33
# 27  2019-11-16          20  15176    71       47
# 28  2019-11-14          20  29794   122      124
# 29  2019-11-24          20  26137   124       86
# 30  2018-11-12          20  19368    45       60
# 31  2019-12-05          20  14108    86       42

# %%
update_videos_df.to_csv('C:/Users/dhckd/Study/CodingWorld/기술과제들/네오플/장지_M.csv')

# %% [markdown]
# # 던파 PC
# ### 재생목록 선정에 있어서 최근까지 업데이트 된 재생목록으로 선정하였다. (총 4개)
# - ▶꼭 봐야될 추천 영상
# - ▶요약정리/분석/설명
# - ▶스펙업 가이드
# - 【꿀팁/스킬트리/설명】

# %%
# '▶꼭 봐야될 추천 영상'의 영상들

update_videos = df['PlayLists'][16]

playlist_videos = youtube.playlistItems().list(playlistId = update_videos,
                                              part = 'snippet',
                                              maxResults = 50) # 50개 동영상 뽑아보기
playlistitems_list_response = playlist_videos.execute()

video_names = []
video_ids = []
date = []

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])


video_df = pd.DataFrame([date, video_names, video_ids]).T
video_df.columns = ['Date', 'Title', 'IDS']



# 해당 각 영상들의 정보 수집

import re

ids = []
dates = []
category_id = []
views = []
likes = []
dislikes = []
comments = []
title = []
mins = [] # 분
secs = [] # 초

for i in range(len(video_df)):
    request = youtube.videos().list(part = 'snippet, contentDetails, statistics',
                                   id = video_df['IDS'][i])
    response = request.execute()
    
    if response['items'] == []:
        ids.append('-')
        dates.append('-')
        category_id.append('-')
        views.append('-')
        likes.append('-')
        dislikes.append('-')
        comments.append('-')
        mins.append('-')
        secs.append('-')
    else:
        title.append(response['items'][0]['snippet']['title'])
        ids.append(video_df['IDS'][i])
        dates.append(response['items'][0]['snippet']['publishedAt'].split('T')[0])
        category_id.append(response['items'][0]['snippet']['categoryId'])
        views.append(response['items'][0]['statistics']['viewCount'])
        likes.append(response['items'][0]['statistics']['likeCount'])
        comments.append(response['items'][0]['statistics']['commentCount'])
        
update_videos_df1 = pd.DataFrame([title, ids, dates, category_id, views, likes, comments]).T
update_videos_df1.columns = ['title', 'video_id', 'date', 'category_id', 'views', 'likes', 'comments']

# %%
update_videos_df1
# Out:
#                                                 title     video_id  \
# 0   신규, 복귀 유저 꼭 보세요! 110만렙 던파 시작 & 파밍 가이드 (레벨업, 캐릭...  4vjE8-DD8VY
# 1       던파 63개 모든 직업 추천 & 설명 가이드 (1티어, 무자본, 노가다 캐릭 등)  Yd1YsGHTOgM
# 2   【던파】 모든 직업 105레벨 에픽 세팅 추천 & 설명 가이드 (MP과소모, 아칸,...  b2PX1p89ffg
# 3   모든 직업에게 1티어인 '상변 + MP 과소모 375%' 세팅 추천 & 설명 가이드...  khP1TwIpmbk
# 4          【던파】 현재 가장 중요한 '명성 올리는 법', '옵션 성장, 이관' 개꿀팁  hJT6bbhyKy0
# 5      꼭 보세요! '파죽성, 노블레스 코드' 입장권 얻는 법 개꿀팁 (플레이 포인트 등)  f12Gj_A32mk
# 6                     【던파】 모든 피로도 회복약 총정리 + 피로도 사용 꿀팁  3C-rQ39_79E
# 7         【던파】 2022 '마법부여' 가이드 (종결 / 가성비 / 공짜 마부 총정리)  2ZAgfsbhwCQ
# 8   【던파】 신규, 복귀 유저가 꼭! 사야되는 아이템 총정리 (칭호, 크리쳐, 오라, ...  D1oUAQ_rG-k
# 9                     【던파】 '파괴된 죽은 자의 성' 완벽 공략 A to Z  AW4Zz18R5Lo
# 10              신규, 복귀 유저 꼭 보세요! '아라드 어드벤처 / 토벌전' 가이드  eiKNaMFviAY
# 11   【던파】 피로도 없어도 갈수있는 컨텐츠 총 정리!! (골드, 에픽소울, 노가다, 광부)  tiOtfeIgsV8
# 12  【던파】 무자본의 희망! '재련' 가이드 (강렬한 기운 모으는법/ 재련 쉽게하는 개...  6eXJkc1NHxw
# 13  【던파】 '추방자의 산맥' 완벽 공략 A to Z (Lv.75~80제 스킬 탈리스만...  UTCNC9LTSHU
# 14                        【던파】 '오즈마 레이드' 완벽 공략 A to Z  v_3MltHSZDE
# 15             【던파】 제 5사도, 무형의 '시로코 레이드' 완벽 공략 A to Z  nVoim7s_Jsc
# 16  【던파】 버퍼 가이드 (캐릭 추천, 템셋팅, 스킬 운용, 꿀팁, 정보등 / 크루세이...  aXpCXjscDv4
# 17               신규, 복귀 유저 꼭 보세요!! 던파 필수 상식 '시즌제'의 개념  j2-HsxhtVxI
#
#           date category_id   views likes comments
# 0   2022-03-16          20  199294  1747      212
# 1   2022-03-26          20  193219   734      112
# 2   2022-04-17          20   80946  1085      169
# 3   2022-04-26          20   49913   615      167
# 4   2022-04-22          20   45393   449       54
# 5   2022-04-24          20   22399   123       29
# 6   2021-12-31          20   40601   186       35
# 7   2022-01-17          20   74520   741       82
# 8   2022-01-13          20   59265   372       33
# 9   2022-03-14          20   67524   413       59
# 10  2022-01-14          20   33438   221       48
# 11  2020-01-22          20  147380  1005      101
# 12  2020-07-18          20   69691   486       61
# 13  2020-08-18          20  109084   803      117
# 14  2021-05-26          20  229064  1108      209
# 15  2020-05-13          20  321215  1670      246
# 16  2021-09-17          20   75188   530      109
# 17  2021-10-30          20   47174   363      100

# %%
# '요약정리 분석 설명'의 영상들

update_videos = df['PlayLists'][20]

playlist_videos = youtube.playlistItems().list(playlistId = update_videos,
                                              part = 'snippet',
                                              maxResults = 50) # 50개 동영상 뽑아보기
playlistitems_list_response = playlist_videos.execute()

video_names = []
video_ids = []
date = []

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])


video_df = pd.DataFrame([date, video_names, video_ids]).T
video_df.columns = ['Date', 'Title', 'IDS']




# 해당 각 영상들의 정보 수집

import re

ids = []
dates = []
category_id = []
views = []
likes = []
dislikes = []
comments = []
title = []
mins = [] # 분
secs = [] # 초

for i in range(len(video_df)):
    request = youtube.videos().list(part = 'snippet, contentDetails, statistics',
                                   id = video_df['IDS'][i])
    response = request.execute()
    
    if response['items'] == []:
        ids.append('-')
        dates.append('-')
        category_id.append('-')
        views.append('-')
        likes.append('-')
        dislikes.append('-')
        comments.append('-')
        mins.append('-')
        secs.append('-')
    else:
        title.append(response['items'][0]['snippet']['title'])
        ids.append(video_df['IDS'][i])
        dates.append(response['items'][0]['snippet']['publishedAt'].split('T')[0])
        category_id.append(response['items'][0]['snippet']['categoryId'])
        views.append(response['items'][0]['statistics']['viewCount'])
        likes.append(response['items'][0]['statistics']['likeCount'])
        comments.append(response['items'][0]['statistics']['commentCount'])
        
update_videos_df2 = pd.DataFrame([title, ids, dates, category_id, views, likes, comments]).T
update_videos_df2.columns = ['title', 'video_id', 'date', 'category_id', 'views', 'likes', 'comments']

# %%
update_videos_df2
# Out:
#                                                 title     video_id  \
# 0   모든 직업에게 1티어인 '상변 + MP 과소모 375%' 세팅 추천 & 설명 가이드...  khP1TwIpmbk
# 1      꼭 보세요! '파죽성, 노블레스 코드' 입장권 얻는 법 개꿀팁 (플레이 포인트 등)  f12Gj_A32mk
# 2          【던파】 현재 가장 중요한 '명성 올리는 법', '옵션 성장, 이관' 개꿀팁  hJT6bbhyKy0
# 3                             요즘 많이 보이는 던린이(뉴비) 스펙 진단  8FT_-l2Ch4A
# 4   【던파】 모든 직업 105레벨 에픽 세팅 추천 & 설명 가이드 (MP과소모, 아칸,...  b2PX1p89ffg
# 5   【던파】 105레벨 에픽 셋팅하는 법, 실제 데미지 상승폭 총정리 (근원, 결전, ...  RvXITZ3Ef1E
# 6   【던파】 110만렙 찍고 해야될 것 간단 정리 (105레벨 에픽, 일반 던전, 노블...  vXDRIjFilGk
# 7   신규, 복귀 유저 꼭 보세요! 110만렙 던파 시작 & 파밍 가이드 (레벨업, 캐릭...  4vjE8-DD8VY
# 8                      꼭 보세요!! 신규 던전들에 숨겨져 있는 신기한 기믹들  60rVbT-1z3c
# 9   【던파】 110만렙 확장 업데이트 전, 반드시 알아둬야 할 꿀팁 (레벨업, 신규 파...  cyx4IE6XH3g
# 10          안보면 쌉손해 봅니다! 꼭 보세요!! '시공간 여행' 이벤트에 숨겨진 비밀  yrN_5HwNSrE
# 11              신규, 복귀 유저 꼭 보세요! '아라드 어드벤처 / 토벌전' 가이드  eiKNaMFviAY
# 12  【던파】 신규, 복귀 유저가 꼭! 사야되는 아이템 총정리 (칭호, 크리쳐, 오라, ...  D1oUAQ_rG-k
# 13                    【던파】 모든 피로도 회복약 총정리 + 피로도 사용 꿀팁  3C-rQ39_79E
# 14  신규, 복귀 유저 꼭 보세요! 2022 던파 시작 & 파밍 가이드 (레벨업, 캐릭터...  7GXaBvLjqtY
# 15  유저들이 놓친 2022 신규 컨텐츠 핵심 정보 + 스토리 정리 (바칼 레이드+스토리...  szs3sag5Hd4
# 16  2021 던페 이후 '신규, 복귀' 유저가 해야할 것 (지금 뭐 해야 하나요?, 캐...  4h-apsqZRok
# 17  【던파】 2021 던페 업데이트 내용 요약 총정리 + 이벤트 보상 (만렙 확장, 신...  lcI6t93v0z0
# 18                   2021 던파 페스티벌 추측! 어떤 업데이트가 공개될까??  rXDBMbxOr4A
# 19                              '지역 던전'으로 알수있는 던파의 미래  THdBGCDzdaI
# 20                            【던파】 요원 '암월비보' 패치 요약 정리  VEkFaqyNILA
# 21                     현재 시점 '신규, 복귀 유저'가 반드시 봐야되는 영상  UuY4WVntqUQ
# 22                    역대급 간담회! 2021 던파로ON 핵심내용 총정리!!!  rNjKD4ZLdFg
# 23                           2021년 던파 업데이트 공개된 내용들 정리  y--3cZ26DME
# 24  【던파】 날먹 시너지 장비 '에테르나' 총정리! (파밍방법, 파밍기간, 성능, 논란...  LMh9PhS6is0
# 25  【던파】 자신에게 맞는 '최적화 셋팅' 받는 꿀팁! (+포인트 모으는법  꿀팁, 에...  dC1FvOH99s8
# 26  【던파】 에픽 12부위 이벤트로 키울만한 '직업 추천' 가이드!  (퓨어딜러, 시너...  c1TawTnrq_s
# 27  2020 던페 2부 총정리! (오즈마 레이드, +12강화권, 에픽 12부위, 프로젝...  UALgVL1s9o4
# 28                                 【던파】 '100제 신화' 티어표  gQeu2GMllmM
# 29               【던파】 100제 에픽/신화 대규모 개편! 이번 떡상한 아이템은?  9qcwCQt1AUQ
# 30  2020년 던페 업데이트 내용 요약 총정리! (여거너 진각성, 검은 연옥, 여귀검사...  Eba72z1PhrM
# 31  【던파】 2020 '점핑 이벤트' 해야 될 것 총정리! (캐릭 추천, 도전 미션, ...  ivGDBOGBWvw
# 32                 【던파】 남거너, 뭐 키울지 고민중이세요?? 직업별 간단 정리  INbyEQntgvY
# 33  【던파】 레전더리를 '종결급 악세'로 만든다! 검은차원 : 균열의징후 리뷰 (검은 ...  1HkGIOwurbg
# 34    【던파】 신규던전 '챌린지 모드' 난이도+보상 총 정리!! #돈 버는 컨텐츠 였어??  YMvgZI-FJlE
# 35  【던파】 100제 파밍던전 '최소 컷트라인' 총 정리! 이렇게 쉽다고?? #겐트황궁...  RYFpNvfu3zU
# 36       【던파】 신규 에픽 '지혜의 산물'의 비밀 #시너지템 #택풀 #마소풀 #아이실드            -
# 37   【던파】 2019 역대급 던페 총정리!! #3차각성 #시로코레이드 #신화에픽 #신규던전  Qif2SLE67YU
# 38               【던파】 던페에 공개되지 않은 대박 정보!! 강정호 디렉터 인터뷰  Kd9MX8Lq5Sk
# 39         【던파】 2019 던페 업데이트 내용 예측! #레이드 #신규던전 #신규 캐릭  QLu_HfUIL6Y
# 40           【던파】 던페 미리보기 #2 '진:이계, 고대던전' 전성기 시절 그 던전  tKJt4VF4t0c
# 41                            【던파】 던페 미리보기, 3차각성 예고!!  6-QosLGPj6c
# 42                   【던파】 2018년 던페는 어땠을까?? 작년 던페 평가하기  3SQCByjsCTk
# 43                  【던파】 2차 각성의서 출시일 (패키지에 대한 심오한 분석)  zzC1Wpb6uv8
# 44      【던파 여름 업데이트】 스토리,떡밥 완벽분석! 마계대전,룬&탈리스만,아라드 대격돌  jooWr0Svyz8
# 45                  【던파】 대규모 여름 업데이트 일정 공개??? 킹리적 갓심-  b_UNEqNGAZI
# 46                (던파) 빛-정호 디렉터의 유저간담회 내용 정리!! 던파로 ON  lF6LDOW9iKo
# 47    (던파) 다음 맵부터 막히는 시너지 세팅 + 쿨초템, 스위칭 등 아이템 밸런스 썰풀기  TKgGDP0KILY
# 48                                               None            -
# 49                                               None  EPbgZzHCQnA
#
#           date category_id   views likes comments
# 0   2022-04-26          20   49913   615      167
# 1   2022-04-24          20   22399   123       29
# 2   2022-04-22          20   45399   449       54
# 3   2022-04-21          20   30283   145       91
# 4   2022-04-17          20   80946  1085      169
# 5   2022-03-19          20   70705   302       84
# 6   2022-03-19          20   83792   501       95
# 7   2022-03-16          20  199298  1747      212
# 8   2022-03-08          20   19928   134       55
# 9   2022-03-02          20   43544   374       95
# 10  2022-01-14          20  100850   740      130
# 11  2022-01-14          20   33438   221       48
# 12  2022-01-13          20   59265   372       33
# 13  2021-12-31          20   40601   186       35
# 14  2021-12-30          20  207667  2117      257
# 15  2021-12-23          20   43350   252       79
# 16  2021-12-19          20   38218   209       72
# 17  2021-12-19          20   47683   256      136
# 18  2021-12-15          20   19254   154       55
# 19  2021-12-15          20   33060   229       91
# 20  2021-11-25          20   23523   125      106
# 21  2021-11-12          20   96323   543      176
# 22  2021-08-20          20   39854   284      234
# 23  2021-04-15          20   22821   100       58
# 24  2021-02-26          20   74481   244      331
# 25  2021-01-26          20   37849   179      108
# 26  2021-01-07          20   79203   218      115
# 27  2020-12-26          20   53182   193      172
# 28  2020-12-25          20  126023   291      146
# 29  2020-12-25          20   80463   208       97
# 30  2020-12-20          20   49256   203      124
# 31  2020-07-10          20  131182   892      199
# 32  2020-04-28          20   51715   188       51
# 33  2020-04-16          20   58241   218       54
# 34  2020-01-12          20   57563   172       78
# 35  2019-12-23          20   54934   271      120
# 36           -           -       -     -        -
# 37  2019-12-15          20   22741    83       67
# 38  2019-12-14          20   40732   196      145
# 39  2019-12-14          20   34900   224      112
# 40  2019-12-06          20   31361   186      113
# 41  2019-12-03          20   16922    88       91
# 42  2019-10-31          20   83864   339      244
# 43  2019-10-24          20   20500   119       80
# 44  2019-09-25          20   15940   105       61
# 45  2019-07-26          20   13374    81       53
# 46  2019-07-21          20   18418    97       69
# 47  2019-06-22          20   25373   157      129
# 48           -           -       -     -        -
# 49  2018-07-20          20   42561   102      258

# %%
# '스펙업 가이드'의 영상들

update_videos = df['PlayLists'][10]

playlist_videos = youtube.playlistItems().list(playlistId = update_videos,
                                              part = 'snippet',
                                              maxResults = 50) # 50개 동영상 뽑아보기
playlistitems_list_response = playlist_videos.execute()

video_names = []
video_ids = []
date = []

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])


video_df = pd.DataFrame([date, video_names, video_ids]).T
video_df.columns = ['Date', 'Title', 'IDS']




# 해당 각 영상들의 정보 수집

import re

ids = []
dates = []
category_id = []
views = []
likes = []
dislikes = []
comments = []
title = []
mins = [] # 분
secs = [] # 초

for i in range(len(video_df)):
    request = youtube.videos().list(part = 'snippet, contentDetails, statistics',
                                   id = video_df['IDS'][i])
    response = request.execute()
    
    if response['items'] == []:
        ids.append('-')
        dates.append('-')
        category_id.append('-')
        views.append('-')
        likes.append('-')
        dislikes.append('-')
        comments.append('-')
        mins.append('-')
        secs.append('-')
    else:
        title.append(response['items'][0]['snippet']['title'])
        ids.append(video_df['IDS'][i])
        dates.append(response['items'][0]['snippet']['publishedAt'].split('T')[0])
        category_id.append(response['items'][0]['snippet']['categoryId'])
        views.append(response['items'][0]['statistics']['viewCount'])
        likes.append(response['items'][0]['statistics']['likeCount'])
        comments.append(response['items'][0]['statistics']['commentCount'])
        
update_videos_df3 = pd.DataFrame([title, ids, dates, category_id, views, likes, comments]).T
update_videos_df3.columns = ['title', 'video_id', 'date', 'category_id', 'views', 'likes', 'comments']

# %%
update_videos_df3
# Out:
#                                                title     video_id        date  \
# 0                     【던파】 스펙업 가이드 1편 : 속성 부여, 속성 선택  -oupU4WGIkg  2021-01-18
# 1        【던파】 2022 '마법부여' 가이드 (종결 / 가성비 / 공짜 마부 총정리)  2ZAgfsbhwCQ  2022-01-17
# 2  【던파】 신규, 복귀 유저가 꼭! 사야되는 아이템 총정리 (칭호, 크리쳐, 오라, ...  D1oUAQ_rG-k  2022-01-13
# 3         【던파】 현재 가장 중요한 '명성 올리는 법', '옵션 성장, 이관' 개꿀팁  hJT6bbhyKy0  2022-04-22
# 4  신규, 복귀 유저 꼭 보세요! 110만렙 던파 시작 & 파밍 가이드 (레벨업, 캐릭...  4vjE8-DD8VY  2022-03-16
# 5             【던파】 스펙업 가이드 3편 : 스위칭 (버프 강화, 딜러 / 버퍼)  Kwhn4WXbsyc  2021-02-11
# 6  【던파】 모든 직업 105레벨 에픽 세팅 추천 & 설명 가이드 (MP과소모, 아칸,...  b2PX1p89ffg  2022-04-17
# 7   【던파】 초보, 무자본 유저 개이득! 가성비 템 다 퍼주는 신규 던전 '엘븐미어' 리뷰  7n6WhmlHLbE  2022-04-13
#
#   category_id   views likes comments
# 0          20   47784   315      139
# 1          20   74523   741       82
# 2          20   59265   372       33
# 3          20   45399   449       54
# 4          20  199298  1747      212
# 5          20   45488   226       35
# 6          20   80946  1085      169
# 7          20   38613   170       48

# %%
# '꿀팁 스킬트리 설명'의 영상들

update_videos = df['PlayLists'][29]

playlist_videos = youtube.playlistItems().list(playlistId = update_videos,
                                              part = 'snippet',
                                              maxResults = 50) # 50개 동영상 뽑아보기
playlistitems_list_response = playlist_videos.execute()

video_names = []
video_ids = []
date = []

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])


video_df = pd.DataFrame([date, video_names, video_ids]).T
video_df.columns = ['Date', 'Title', 'IDS']




# 해당 각 영상들의 정보 수집

import re

ids = []
dates = []
category_id = []
views = []
likes = []
dislikes = []
comments = []
title = []
mins = [] # 분
secs = [] # 초

for i in range(len(video_df)):
    request = youtube.videos().list(part = 'snippet, contentDetails, statistics',
                                   id = video_df['IDS'][i])
    response = request.execute()
    
    if response['items'] == []:
        ids.append('-')
        dates.append('-')
        category_id.append('-')
        views.append('-')
        likes.append('-')
        dislikes.append('-')
        comments.append('-')
        mins.append('-')
        secs.append('-')
    else:
        title.append(response['items'][0]['snippet']['title'])
        ids.append(video_df['IDS'][i])
        dates.append(response['items'][0]['snippet']['publishedAt'].split('T')[0])
        category_id.append(response['items'][0]['snippet']['categoryId'])
        views.append(response['items'][0]['statistics']['viewCount'])
        likes.append(response['items'][0]['statistics']['likeCount'])
        comments.append(response['items'][0]['statistics']['commentCount'])
        
update_videos_df4 = pd.DataFrame([title, ids, dates, category_id, views, likes, comments]).T
update_videos_df4.columns = ['title', 'video_id', 'date', 'category_id', 'views', 'likes', 'comments']

# %%
update_videos_df4
# Out:
#                                                 title     video_id  \
# 0                                     개꿀 보상 활용하는 법 꿀팁  oBtFDo1fxW8
# 1   근원 vs 결전의 무기, 어떤걸 받아야될까? 많이 나오는 질문, 꿀팁 총정리 (지난...  mBa0MaPPlxM
# 2   【던파】 '비트 앤 전설' 공략 + 보상 총정리! (돈 버는법, 메카타우, 기간, ...  DOs8qT1MKEQ
# 3                         초보도 쉽게 '골드 많이 버는법' 개꿀팁 - 2편  vIDObu-Itb4
# 4                       초보도 할수있는 '골드 많이 버는법' 개꿀팁 - 1편  FE19lMPSngk
# 5   【던파】 오즈마 레이드 단계별 컷트라인 + 보상 정리 (던오프 1시, 버프력, 0단...  e-DJbGaMGW4
# 6        【던파】 포샤 + 히만스텔라 상점 꼭 사야될 아이템 총정리 (음표, 금빛 음표)  7U4PhY81Ve4
# 7   【던파】 초보도 쉽게 따라하는 '블레이드 이벤트' 가이드 (지역던전, 블레이드의 노...  RBndEEwUZfQ
# 8                           【던파】 '음표' 모으는법 꿀팁 + 던전 추천  fafOI0BHGK0
# 9   안보면 쌉손해! 에테르나 개꿀팁 모음 (장비추천/탐험레벨/무기/캐릭터/파밍방법/셋팅...  vUoeV2HJlJM
# 10  【던파】 꼭 사야될 '필수 아이템'들 총정리! (딜러, 버퍼 - 칭호, 크리쳐, 오...  gAq5gj23WqU
# 11                          【던파】 '신화' 나오는 모든 컨텐츠 총정리!  3tVi70oEBR8
# 12                          【던파】 '에픽' 나오는 모든 컨텐츠 총정리!  BR3L46v-wVk
# 13  【던파】 요원 가이드 (스킬트리, 100제 에픽 추천, 칭호, 크리쳐, 스킬콤보, ...  U9Wztv7-boQ
# 14        【던파】 진:데몬슬레이어 25초 콤보 및 스킬트리 ('탈리스만 선택' 활용법)  MnNT47mHYg8
# 15  【던파】 모든 직업 '탈리스만 & 룬' 추천 가이드 (마계대전, 추방자의 산맥, 카...  pqxW6tU7KnA
# 16  【던파】 '스킬 칭호' 완벽 가이드 (스킬칭호 선택 & 구매하는 법, 검제 삼화취정...  dkfoIrnguZM
# 17  【던파】 '신규 & 복귀 유저 가이드' 해야될 것, 파밍루트 총정리! (무자본, 중...  66dBB-aG4LY
# 18  【던파】 +12 강화권 '무기 얻는법' 개꿀팁! 초보들 꼭 보세요 제발 (새김, 계...  nWwZ5_tL8ZI
# 19  【던파】 이번 사건 '보상' 설명 & 추천 가이드(교불 클레압, 12강화권, 찬란한...  pLKrJmxV01c
# 20  【던파】 비트앤파이터 공략! (캐릭터 능력치, 스탯, 돈 버는법, 건물, 레어소울 ...  uOJHAStHvoI
# 21                  【던파】 에픽초돌, 어떤 템에 써야 좋을까? 개이득 보는법!  UZ887jXXTjY
# 22  【던파】 던린이라면 꼭 봐야될 '개이득 꿀팁' 10가지 : 1편 (버퍼, 버프강화,...  4Uy7G4NOuSI
# 23                  【던파】 현재 메타 10사기템 '아린 비극의 잔해' 사용법!  DpjlfIMs-SE
# 24  【던파】 던담 2조? 3조? 시로코 전, 꼭 알아야될 스펙에 대한 사실! 12가지 ...  2_5iTlc5JYU
# 25  【던파】 '강화'하는법 핵꿀팁 정리! (강화 확률 올리는법, 공짜로 강화하는법, 새...  IvDHMca_gq0
# 26   【던파】 피로도 없어도 갈수있는 컨텐츠 총 정리!! (골드, 에픽소울, 노가다, 광부)  tiOtfeIgsV8
# 27  【던파】 무자본으로 '시간의인도석, 에픽소울' 모으기 대박 꿀팁!! (지혜의인도, ...            -
# 28  【던파】 많이 나오는 질문 Q&A #칭호 #크리쳐 #오라 #100제에픽효율 #새김 ...  T5KZ-aqdTjw
# 29  【던파】 신규, 복귀 유저를 위한 만렙+파밍 가이드 #만렙찍기 #아이템파밍 #크리쳐...  8_4ddq2EcyE
# 30  【던파】 100제 지옥파티 '지혜의 인도'의 모든 정보 #보상 #입장재료 #난이도 ...  6jxDvLkDni4
# 31                     【던파】 초대장 모아두세요! + 초대장 모으는 법 꿀팁  9aj66D-3mgo
# 32                             던파 복귀 고민 하시는 분들, 꿀팁(?)  ONWTMgZNKXI
# 33             【던파】 정령왕학개론, 정령왕에 대한 모든것 #스위칭 #효율 #몰레크  7c96VfBI7YA
# 34                  【던파】 마계대전 특별던전, 효율 좋나요?? 정리 했습니다.  nSheDPD0Sww
# 35                       【던파】 마계대전 에픽퀘스트, 꼭 하세요!!! 제발  S8E-doTM5aY
# 36                  【던파】 그래픽, 시스템 설정법 (커맨드+단축키 꿀팁까지!)  MUJvaw_uKPU
# 37                【던파】 갑자기 떡상한 아이템?? 빨리 꿀 빠세요!! 개꿀팁;;  Er9M2uF4QDI
# 38              【던파】 초보 맞춤형 스킬칭호 가이드 - 지옥의 정복자 패키지 설명  NhmIQKs5dEw
# 39     (던파) 완벽가이드 - 소울에 대한 모든것 (스킬트리 설명 템셋팅 할렘 테이 등등)  BmcpkNYbD7g
# 40             (던파) 버퍼, 레이드에서 스킬운용 꿀팁!! (세라핌,헤카테,세인트)  vrZN6ky1V7M
# 41  (던파) 혐사꾼에게 속지마세요!! '교환 불가 클론 레압' 싸게사는 꿀팁 (교불클,...  AGsrP9Mgfi8
# 42          (던파) 신규 스킬트리 공유 - 검마,매챙추,총검사,소울,이단,리디머 등등  aDdBoNRNXxI
# 43           (던파) 테이방어구 추천영상 Q&A, -패파는 창천? 카운터포? 온슬롯?  RxFy9feqnRE
# 44                      (던파) 프레이-이시스 레이드, 쩔 받는법 설명 영상  n5K-YoK2x5s
# 45                     (던파) 무기스킨 적용법 설명!! 장지의 무기선택은??  WLalA22xrvQ
# 46                   (던파) 다크랜서(에레보스) 스킬트리 및 20초 콤보 영상  8qnB2dNRLDA
# 47         (던파) 데미지를 올리고 싶다면?? 이 영상을 보세요 (스펙업 하는 방법들)  AQyO2uu3-Pw
# 48             (던파) 드래고니안랜서(제노사이더) 스킬트리 및 20초 콤보 입니다.  FZMCGm4VMRg
# 49                                               None  g99geGjaU6I
#
#           date category_id   views likes comments
# 0   2022-04-20          20   34495   156       47
# 1   2022-03-17          20   61691   211       87
# 2   2021-10-22          20   37629   185       25
# 3   2021-09-26          20   40993   256       49
# 4   2021-08-12          20   91488   589      109
# 5   2021-07-24          20   38565   156      105
# 6   2021-07-23          20   20804   138       27
# 7   2021-07-22          20   36629   199       44
# 8   2021-07-10          20   60059   377       80
# 9   2021-03-07          20   73350   316       97
# 10  2021-02-01          20   66213   384       74
# 11  2021-01-14          20   45740   260       76
# 12  2021-01-13          20   53101   379       86
# 13  2020-10-28          20   50780   376       69
# 14  2020-10-12          20   20042    97       40
# 15  2020-10-06          20  124746   633      167
# 16  2020-09-24          20   26426   143       39
# 17  2020-09-23          20  188859  1275      194
# 18  2020-09-18          20   68216   453      145
# 19  2020-09-17          20   74947   317      243
# 20  2020-08-07          20   30703   136       47
# 21  2020-07-23          20   30926   140       61
# 22  2020-07-19          20   26543   209       39
# 23  2020-05-28          20   33700   113       69
# 24  2020-05-06          20   44158   193       84
# 25  2020-01-24          20   42662   163       72
# 26  2020-01-22          20  147380  1005      101
# 27           -           -       -     -        -
# 28  2020-01-11          20  279168  1594      135
# 29  2020-01-11          20   58306   346       92
# 30  2020-01-09          20  169145   897      259
# 31  2020-01-06          20  103847   631       91
# 32  2019-12-15          20   16636    89       26
# 33  2019-11-12          20   12052    99       58
# 34  2019-10-29          20   16652   120       64
# 35  2019-08-30          20   11909    65       42
# 36  2019-08-24          20   43091   172       72
# 37  2019-08-09          20   58805   335       76
# 38  2019-08-06          20   27706   120       78
# 39  2019-08-02          20    8429    76       38
# 40  2019-07-01          20   60737   304       99
# 41  2019-05-21          20   20604    88       31
# 42  2019-05-16          20   38413   179       50
# 43  2019-05-11          20   20584    84       27
# 44  2019-05-10          20   12057    50       45
# 45  2019-05-08          20   49659   147       20
# 46  2019-04-12          20   31200    65       25
# 47  2019-03-28          20   12496    36       11
# 48  2019-03-28          20   16764    66       37
# 49  2019-03-27          20   12068    45       12

# %%
# 4개의 재생목록 데이터 프레임 합치기
df_PC = pd.concat([update_videos_df1, update_videos_df2, update_videos_df3, update_videos_df4])

# %%
# 합친 데이터 날짜별로 정렬
df_PC = df_PC.sort_values(by = 'date', ascending = True)

# %%
# df_PC.to_csv('C:/Users/dhckd/Study/CodingWorld/기술과제들/네오플/장지_PC.csv')

# %%
# update_videos_df.to_csv('C:/Users/dhckd/Study/CodingWorld/기술과제들/네오플/장지_M.csv')

# %%
df_M = pd.read_csv('C:/Users/dhckd/Study/CodingWorld/기술과제들/네오플/장지_M.csv', index_col = 0)

# %%
df_PC = pd.read_csv('C:/Users/dhckd/Study/CodingWorld/기술과제들/네오플/장지_PC.csv', index_col = 0)

# %%
df_M = df_M.sort_values(by = 'date', ascending = True)

# %%
df_PC = df_PC.sort_values(by = 'date', ascending = True)

# %% [markdown]
# ### 던파 PC 그래프

# %%
# 데이터 필터링. 
# - 값 가진 데이터 제거
condition = df_PC.video_id != '-'
df_PC_new = df_PC.loc[condition, :]
# 2월 24일 이후 데이터 확인. 던파 PC가 던파 M이 출시됨에 따라 조회수가 변동하였는지 보기위해
condition2 = df_PC_new.date >= '2022-02-24'
df_PC_new = df_PC_new.loc[condition2, :]
# 결측값 제거
df_PC_new = df_PC_new.dropna()

# views 데이터 타입 str에서 int로 변경
df_PC_new = df_PC_new.astype({'views':'int'})

# %%
# 한 날짜에 여러 동영상을 올리는 경우가 있다. 
# 이 경우엔 여러 영상들의 조회수 합을 구해야하기 때문에 groupby 사용
df_PC_new_views = df_PC_new.groupby('date').sum()

# %%
xs = df_PC_new_views.index
ys = df_PC_new_views['views']
plt.figure(figsize=(10, 6)) #그래프 크기 지정
plt.xlabel('Date') #그래프 x축 이름(label) 지정
plt.ylabel('views') #그래프 y축 이름(label) 지정
plt.xticks(rotation = 90)
plt.title('유튜버 장지의 던파 PC 조회수(2월 24일 ~ 현재)',fontsize=20) ## 타이틀 설정
plt.bar(xs, ys, width=0.6) #리스트로 저장한 xs와 ys로 막대(bar) 그래프 플롯
# Out:
# <BarContainer object of 14 artists>

# %% [markdown]
# ### 던파 M 그래프

# %%
# 데이터 필터링. 
# - 값 가진 데이터 제거
condition = df_M.video_id != '-'
df_M_new = df_M.loc[condition, :]
# 3월 24일 이전 데이터 제거. 던파 M이니까
condition2 = df_M_new.date >= '2022-03-24'
df_M_new = df_M_new.loc[condition2, :]
# 결측값 제거
df_M_new = df_M_new.dropna()

# views 데이터 타입 str에서 int로 변경
df_M_new = df_M_new.astype({'views':'int'})

# %%
# 한 날짜에 여러 동영상을 올리는 경우가 있다. 이 경우엔 영상들의 조회수 합을 구해야하기 때문에 groupby 사용
df_M_new_views = df_M_new.groupby('date').sum()

# %%
xs = df_M_new_views.index
ys = df_M_new_views['views']
plt.figure(figsize=(10, 6)) #그래프 크기 지정
plt.xlabel('Date') #그래프 x축 이름(label) 지정
plt.ylabel('views') #그래프 y축 이름(label) 지정
plt.xticks(rotation = 90)
plt.title('유튜버 장지의 던파 M 조회수(3월 24일 ~ 현재)',fontsize=20) ## 타이틀 설정
plt.bar(xs, ys, width=0.6) #리스트로 저장한 xs와 ys로 막대(bar) 그래프 플롯
# Out:
# <BarContainer object of 14 artists>
